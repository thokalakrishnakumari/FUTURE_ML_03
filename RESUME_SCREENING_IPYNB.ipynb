# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

job = ["Python Machine Learning Data Analysis"]

resumes = [
    "Python Machine Learning SQL",
    "Java Spring Boot",
    "Python Data Analysis Pandas"
]

names = ["Candidate A", "Candidate B", "Candidate C"]

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(job + resumes)

scores = cosine_similarity(X[0:1], X[1:]).flatten()

for name, score in zip(names, scores):
    print(name, "Score:", round(score * 100, 2), "%")
# Out:
# Candidate A Score: 67.08 %
# Candidate B Score: 0.0 %
# Candidate C Score: 67.08 %
